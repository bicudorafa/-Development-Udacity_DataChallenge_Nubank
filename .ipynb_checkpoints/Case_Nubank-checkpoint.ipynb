# %% [markdown]
# # Abertura dos arquivos

# %% [markdown]
# Configurações iniciais para iniciar exploração

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno
import gc
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Leitura preliminar dos arquivos

# %%
acquisition = pd.read_csv('data/acquisition_train.csv')
acquisition.head()
# Out:
#                                     ids target_default  \
# 0  343b7e7b-2cf8-e508-b8fd-0a0285af30aa          False
# 1  bc2c7502-bbad-0f8c-39c3-94e881967124          False
# 2  669630dd-2e6a-0396-84bf-455e5009c922           True
# 3  d235609e-b6cb-0ccc-a329-d4f12e7ebdc1          False
# 4  9e0eb880-e8f4-3faa-67d8-f5cdd2b3932b          False
#
#                     score_1                   score_2  score_3     score_4  \
# 0  1Rk8w4Ucd5yR3KcqZzLdow==  IOVu8au3ISbo6+zmfnYwMg==    350.0  101.800832
# 1  DGCQep2AE5QRkNCshIAlFQ==  SaamrHMo23l/3TwXOWgVzw==    370.0   97.062615
# 2  DGCQep2AE5QRkNCshIAlFQ==  Fv28Bz0YRTVAT5kl1bAV6g==    360.0  100.027073
# 3  1Rk8w4Ucd5yR3KcqZzLdow==  dCm9hFKfdRm7ej3jW+gyxw==    510.0  101.599485
# 4  8k8UDR4Yx0qasAjkGrUZLw==  +CxEO4w7jv3QPI/BQbyqAA==    500.0   98.474289
#
#     score_5     score_6  risk_rate  last_amount_borrowed     ...       \
# 0  0.259555  108.427273       0.40              25033.92     ...
# ...

# %%
print ("Rows     : " ,acquisition.shape[0])
print ("Columns  : " ,acquisition.shape[1])
print ("\nFeatures : \n" ,acquisition.columns.tolist())
print ("\nMissing values :  ", acquisition.isnull().sum().values.sum())
print ("\nUnique values :  \n",acquisition.nunique())
# Out:
# Rows     :  45000
# Columns  :  43
#
# Features :
#  ['ids', 'target_default', 'score_1', 'score_2', 'score_3', 'score_4', 'score_5', 'score_6', 'risk_rate', 'last_amount_borrowed', 'last_borrowed_in_months', 'credit_limit', 'reason', 'income', 'facebook_profile', 'state', 'zip', 'channel', 'job_name', 'real_state', 'ok_since', 'n_bankruptcies', 'n_defaulted_loans', 'n_accounts', 'n_issues', 'application_time_applied', 'application_time_in_funnel', 'email', 'external_data_provider_credit_checks_last_2_year', 'external_data_provider_credit_checks_last_month', 'external_data_provider_credit_checks_last_year', 'external_data_provider_email_seen_before', 'external_data_provider_first_name', 'external_data_provider_fraud_score', 'lat_lon', 'marketing_channel', 'profile_phone_number', 'reported_income', 'shipping_state', 'shipping_zip_code', 'profile_tags', 'user_agent', 'target_fraud']
#
# Missing values :   219437
#
# Unique values :
# ...

# %%
acquisition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 43 columns):
# ids                                                 45000 non-null object
# target_default                                      41741 non-null object
# score_1                                             44438 non-null object
# score_2                                             44438 non-null object
# score_3                                             44438 non-null float64
# score_4                                             45000 non-null float64
# score_5                                             45000 non-null float64
# score_6                                             45000 non-null float64
# risk_rate                                           44438 non-null float64
# last_amount_borrowed                                15044 non-null float64
# last_borrowed_in_months                             15044 non-null float64
# ...

# %%
def catTargetPlot (cat):
    sns.countplot(y = cat, hue = 'target_default', data = acquisition)
catTargetPlot ('score_1')

# %%
catTargetPlot('score_2')

# %%
catTargetPlot ('last_borrowed_in_months')

# %%
catTargetPlot ('facebook_profile')

# %%
catTargetPlot ('target_fraud')

# %%
catTargetPlot('email')

# %%
catTargetPlot('email')s

# %%
acquisition.score_3.plot(kind = 'hist')

# %%
acquisition.score_4.plot(kind = 'hist')

# %%
sns.lmplot(x = 'score_3', y = 'score_4', data = acquisition)

# %%
plt.figure(figsize=(5,5))

plt.title('Percentage of Default')
acquisition['target_default'].value_counts().plot(kind='pie', table=True, autopct='%1.1f%%',
counterclock=False, shadow=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-3576e9a72adc> in <module>()
#       1 latLon = pd.DataFrame(columns = ['lat', 'lon'])
# ----> 2 for lat, lon in acquisition.lat_lon:
#       3     latLon.append({'lat': lat}, ignore_index=True)
#       4     latLon.append({'lon': lon}, ignore_index=True)
#       5 latLon.head()
#
# ValueError: too many values to unpack (expected 2)

# %%
# Out:
# count                                         43637
# unique                                        22412
# top       (-5.164423488858103, -37.356920426246845)
# freq                                             18
# Name: lat_lon, dtype: object

# %%
sns.boxplot(y = 'last_amount_borrowed', x = 'target_default', data = acquisition)
sns.boxplot(y = 'n_defaulted_loans', x = 'target_default', data = acquisition)
# tentei risk_rate também e bem fraco

# %% [markdown]
# Algumas Considerações sobre algumas variáveis:
# Contínuas:
# risk_rate e n_defaulted_loans possuem pouco influência direta na variável
# Os scores de credito tem nenhuma tendência linear ou agrupamento em relação ao target
# Categóricas:
# channel é totalmente desprezível
# real_state, n_bankruptcies possui 2 categorias praticamente inexistentes
# n_defaulted_loans só possui 1 realmente relevante (1)
