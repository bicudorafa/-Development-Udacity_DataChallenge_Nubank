# %% [markdown]
# # Abertura dos arquivos

# %% [markdown]
# Configurações iniciais para iniciar exploração

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno
import gc
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# ajuda a otimizar o uso da memória (mais info: https://www.geeksforgeeks.org/garbage-collection-python/)
gc.enable()

# %% [markdown]
# Função para colher 1as impressões do df:

# %%
def summary_info_df (df):
    print ("Rows     : " ,df.shape[0])
    print ("Columns  : " ,df.shape[1])
    print ("\nFeatures : \n" ,df.columns.tolist())
    print ("\nMissing values :  ", df.isnull().sum().values.sum())
    print ("\nUnique values :  \n",df.nunique())
    print ("\nData Types :  \n",df.dtypes)

# %% [markdown]
# Leitura preliminar dos arquivos

# %%
acquisition = pd.read_csv('data/acquisition_train.csv')
acquisition.head()
# Out:
#                                     ids target_default  \
# 0  343b7e7b-2cf8-e508-b8fd-0a0285af30aa          False
# 1  bc2c7502-bbad-0f8c-39c3-94e881967124          False
# 2  669630dd-2e6a-0396-84bf-455e5009c922           True
# 3  d235609e-b6cb-0ccc-a329-d4f12e7ebdc1          False
# 4  9e0eb880-e8f4-3faa-67d8-f5cdd2b3932b          False
#
#                     score_1                   score_2  score_3     score_4  \
# 0  1Rk8w4Ucd5yR3KcqZzLdow==  IOVu8au3ISbo6+zmfnYwMg==    350.0  101.800832
# 1  DGCQep2AE5QRkNCshIAlFQ==  SaamrHMo23l/3TwXOWgVzw==    370.0   97.062615
# 2  DGCQep2AE5QRkNCshIAlFQ==  Fv28Bz0YRTVAT5kl1bAV6g==    360.0  100.027073
# 3  1Rk8w4Ucd5yR3KcqZzLdow==  dCm9hFKfdRm7ej3jW+gyxw==    510.0  101.599485
# 4  8k8UDR4Yx0qasAjkGrUZLw==  +CxEO4w7jv3QPI/BQbyqAA==    500.0   98.474289
#
#     score_5     score_6  risk_rate  last_amount_borrowed     ...       \
# 0  0.259555  108.427273       0.40              25033.92     ...
# 1  0.942655   92.002546       0.24                   NaN     ...
# 2  0.351918  112.892453       0.29               7207.92     ...
# 3  0.987673   94.902491       0.32                   NaN     ...
# 4  0.532539  118.126207       0.18                   NaN     ...
#
#    external_data_provider_fraud_score  \
# 0                                 645
# 1                                 243
# 2                                  65
# 3                                 815
# 4                                 320
#
#                                       lat_lon marketing_channel  \
# 0    (-29.151545708122246, -51.1386461804385)      Invite-email
# 1   (-19.687710705798963, -47.94151536525154)  Radio-commercial
# 2  (-28.748023890412284, -51.867279334353995)      Waiting-list
# 3   (-17.520650158450454, -39.75801139933186)      Waiting-list
# 4   (-16.574259446978008, -39.90990074785962)      Invite-email
#
#    profile_phone_number reported_income shipping_state shipping_zip_code  \
# 0           514-9840782         57849.0          BR-MT             17528
# 1           251-3659293          4902.0          BR-RS             40933
# 2           230-6097993        163679.0          BR-RR             50985
# 3           261-3543751          1086.0          BR-RN             37825
# 4           102-3660162        198618.0          BR-MT             52827
#
#                                 profile_tags  \
# 0                    {'tags': ['n19', 'n8']}
# 1              {'tags': ['n6', 'n7', 'nim']}
# 2       {'tags': ['n0', 'n17', 'nim', 'da']}
# 3                           {'tags': ['n4']}
# 4  {'tags': ['pro+aty', 'n19', 'da', 'b19']}
#
#                                           user_agent target_fraud
# 0  Mozilla/5.0 (Linux; Android 6.0.1; SGP771 Buil...          NaN
# 1  Mozilla/5.0 (Linux; Android 5.0.2; SAMSUNG SM-...          NaN
# 2  Mozilla/5.0 (Linux; Android 6.0.1; SGP771 Buil...          NaN
# 3  Mozilla/5.0 (Linux; Android 6.0; HTC One X10 B...          NaN
# 4  Mozilla/5.0 (Linux; Android 7.0; Pixel C Build...          NaN
#
# [5 rows x 43 columns]

# %%
summary_info_df(acquisition)
# Out:
# Rows     :  45000
# Columns  :  43
#
# Features :
#  ['ids', 'target_default', 'score_1', 'score_2', 'score_3', 'score_4', 'score_5', 'score_6', 'risk_rate', 'last_amount_borrowed', 'last_borrowed_in_months', 'credit_limit', 'reason', 'income', 'facebook_profile', 'state', 'zip', 'channel', 'job_name', 'real_state', 'ok_since', 'n_bankruptcies', 'n_defaulted_loans', 'n_accounts', 'n_issues', 'application_time_applied', 'application_time_in_funnel', 'email', 'external_data_provider_credit_checks_last_2_year', 'external_data_provider_credit_checks_last_month', 'external_data_provider_credit_checks_last_year', 'external_data_provider_email_seen_before', 'external_data_provider_first_name', 'external_data_provider_fraud_score', 'lat_lon', 'marketing_channel', 'profile_phone_number', 'reported_income', 'shipping_state', 'shipping_zip_code', 'profile_tags', 'user_agent', 'target_fraud']
#
# Missing values :   219437
#
# Unique values :
#  ids                                                 45000
# target_default                                          2
# score_1                                                 7
# score_2                                                35
# score_3                                                88
# score_4                                             45000
# score_5                                             45000
# score_6                                             45000
# risk_rate                                              82
# last_amount_borrowed                                14325
# last_borrowed_in_months                                 2
# credit_limit                                        20928
# reason                                              14874
# income                                              41211
# facebook_profile                                        2
# state                                                  50
# zip                                                   823
# channel                                                 1
# job_name                                            32265
# real_state                                              5
# ok_since                                              100
# n_bankruptcies                                          6
# n_defaulted_loans                                       5
# n_accounts                                             44
# n_issues                                               44
# application_time_applied                            35543
# application_time_in_funnel                            501
# email                                                   6
# external_data_provider_credit_checks_last_2_year        1
# external_data_provider_credit_checks_last_month         4
# external_data_provider_credit_checks_last_year          2
# external_data_provider_email_seen_before               62
# external_data_provider_first_name                   32886
# external_data_provider_fraud_score                   1001
# lat_lon                                             22412
# marketing_channel                                       9
# profile_phone_number                                45000
# reported_income                                     40025
# shipping_state                                         25
# shipping_zip_code                                   28263
# profile_tags                                        26131
# user_agent                                            297
# target_fraud                                            2
# dtype: int64
#
# Data Types :
#  ids                                                  object
# target_default                                       object
# score_1                                              object
# score_2                                              object
# score_3                                             float64
# score_4                                             float64
# score_5                                             float64
# score_6                                             float64
# risk_rate                                           float64
# last_amount_borrowed                                float64
# last_borrowed_in_months                             float64
# credit_limit                                        float64
# reason                                               object
# income                                              float64
# facebook_profile                                     object
# state                                                object
# zip                                                  object
# channel                                              object
# job_name                                             object
# real_state                                           object
# ok_since                                            float64
# n_bankruptcies                                      float64
# n_defaulted_loans                                   float64
# n_accounts                                          float64
# n_issues                                            float64
# application_time_applied                             object
# application_time_in_funnel                            int64
# email                                                object
# external_data_provider_credit_checks_last_2_year    float64
# external_data_provider_credit_checks_last_month       int64
# external_data_provider_credit_checks_last_year      float64
# external_data_provider_email_seen_before            float64
# external_data_provider_first_name                    object
# external_data_provider_fraud_score                    int64
# lat_lon                                              object
# marketing_channel                                    object
# profile_phone_number                                 object
# reported_income                                     float64
# shipping_state                                       object
# shipping_zip_code                                     int64
# profile_tags                                         object
# user_agent                                           object
# target_fraud                                         object
# dtype: object

# %%
spend = pd.read_csv('data/spend_train.csv')
spend.head()
# Out:
#                                     ids  credit_line  month    spends  \
# 0  b4118fd5-77d5-4d80-3617-bacd7aaf1a88        17941      0   6305.06
# 1  b4118fd5-77d5-4d80-3617-bacd7aaf1a88        17941      1   4199.99
# 2  b4118fd5-77d5-4d80-3617-bacd7aaf1a88        17941      2   7167.94
# 3  b4118fd5-77d5-4d80-3617-bacd7aaf1a88        17941      3  16631.05
# 4  b4118fd5-77d5-4d80-3617-bacd7aaf1a88        17941      4    115.29
#
#    revolving_balance  card_request  minutes_cs
# 0              35.56             1        0.00
# 1            3406.59             0        0.00
# 2               0.00             0        0.00
# 3               0.00             1        5.55
# 4               0.00             0        6.89

# %%
summary_info_df(spend)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-abd1af728857> in <module>()
# ----> 1 summary_info_df(spend)
#
# NameError: name 'spend' is not defined

# %%
teste = pd.read_csv('data/acquisition_test.csv')

# %%
summary_info_df(teste)
# Out:
# Rows     :  19592
# Columns  :  41
#
# Features :
#  ['ids', 'score_1', 'score_2', 'score_3', 'score_4', 'score_5', 'score_6', 'risk_rate', 'last_amount_borrowed', 'last_borrowed_in_months', 'credit_limit', 'reason', 'income', 'facebook_profile', 'state', 'zip', 'channel', 'job_name', 'real_state', 'ok_since', 'n_bankruptcies', 'n_defaulted_loans', 'n_accounts', 'n_issues', 'application_time_applied', 'application_time_in_funnel', 'email', 'external_data_provider_credit_checks_last_2_year', 'external_data_provider_credit_checks_last_month', 'external_data_provider_credit_checks_last_year', 'external_data_provider_email_seen_before', 'external_data_provider_first_name', 'external_data_provider_fraud_score', 'lat_lon', 'marketing_channel', 'profile_phone_number', 'reported_income', 'shipping_state', 'shipping_zip_code', 'profile_tags', 'user_agent']
#
# Missing values :   74559
#
# Unique values :
#  ids                                                 19592
# score_1                                                 7
# score_2                                                35
# score_3                                                80
# score_4                                             19592
# score_5                                             19592
# score_6                                             19592
# risk_rate                                              74
# last_amount_borrowed                                 6451
# last_borrowed_in_months                                 2
# credit_limit                                        10032
# reason                                               7303
# income                                              18702
# facebook_profile                                        2
# state                                                  48
# zip                                                   794
# channel                                                 1
# job_name                                            15011
# real_state                                              5
# ok_since                                               89
# n_bankruptcies                                          6
# n_defaulted_loans                                       3
# n_accounts                                             40
# n_issues                                               39
# application_time_applied                            17599
# application_time_in_funnel                            501
# email                                                   5
# external_data_provider_credit_checks_last_2_year        1
# external_data_provider_credit_checks_last_month         4
# external_data_provider_credit_checks_last_year          2
# external_data_provider_email_seen_before               62
# external_data_provider_first_name                   17011
# external_data_provider_fraud_score                   1001
# lat_lon                                             13678
# marketing_channel                                       9
# profile_phone_number                                19592
# reported_income                                     18470
# shipping_state                                         25
# shipping_zip_code                                   15858
# profile_tags                                        12243
# user_agent                                            297
# dtype: int64
#
# Data Types :
#  ids                                                  object
# score_1                                              object
# score_2                                              object
# score_3                                             float64
# score_4                                             float64
# score_5                                             float64
# score_6                                             float64
# risk_rate                                           float64
# last_amount_borrowed                                float64
# last_borrowed_in_months                             float64
# credit_limit                                        float64
# reason                                               object
# income                                              float64
# facebook_profile                                     object
# state                                                object
# zip                                                  object
# channel                                              object
# job_name                                             object
# real_state                                           object
# ok_since                                            float64
# n_bankruptcies                                      float64
# n_defaulted_loans                                   float64
# n_accounts                                          float64
# n_issues                                            float64
# application_time_applied                             object
# application_time_in_funnel                            int64
# email                                                object
# external_data_provider_credit_checks_last_2_year    float64
# external_data_provider_credit_checks_last_month       int64
# external_data_provider_credit_checks_last_year      float64
# external_data_provider_email_seen_before            float64
# external_data_provider_first_name                    object
# external_data_provider_fraud_score                    int64
# lat_lon                                              object
# marketing_channel                                    object
# profile_phone_number                                 object
# reported_income                                     float64
# shipping_state                                       object
# shipping_zip_code                                     int64
# profile_tags                                         object
# user_agent                                           object
# dtype: object

# %% [markdown]
# # Data Cleaning

# %%
acquisition.reported_income.replace([np.inf, -np.inf], np.nan, inplace = True)

# %%
teste.reported_income.replace([np.inf, -np.inf], np.nan, inplace = True)

# %% [markdown]
# ### Modificações Preliminares

# %%
#from datetime import datetime
#datetime.strptime(acquisition.application_time_applied, '%H:%M:%S')
#acquisition.application_time_applied = acquisition.application_time_applied.map(lambda x: datetime.strptime(x, '%H:%M:%S'))
# valores como 00:60:02 inviabilizam o rolê

# %% [markdown]
# Separação do DF de treino dos targets e formação do combo set.

# %%
acquisition_bl_X = acquisition.iloc[:, 2:-1].copy()
acquisition_bl_y = acquisition[['target_default']].copy().astype('bool')
fraud_bl_y = acquisition[['target_fraud']].copy()
combo_x_bl = pd.concat([acquisition_bl_X, teste.iloc[:, 1:].copy()])

# %% [markdown]
# Variáveis descartadas por não terem informação facilmente obtíveis, ou conseguidas via outras variáveis. Poderiam ser melhor trabalhadas em outra oportunidade: lat_lon (poderia dar origem a 2 features novas para realização de clusterização, ou analisar a interação quantitativa da região), application_time_applied (se se entendesse a raiz do problema com horários com 60 min), external_data_provider_first_name (NLP, embora a maioria dos nomes não se repita).

# %%
discVars = ['zip', 'job_name', 'lat_lon', 'profile_phone_number', 'application_time_applied','shipping_zip_code', 'profile_tags',
            'user_agent', 'reason', 'external_data_provider_first_name']
combo_x_bl[discVars]
# Out:
#                             zip  \
# 0      Ernn+uVXCMq/6ARrBCcd+A==
# 1      rlWIXTBO+VOa34+SpGyhlQ==
# 2      PjTIDfJsK0DKL9fO7vuW2g==
# 3      Cc/kWDLQH3dpHv5HU+pLVA==
# 4      i036nmJ7rfxo+3EvCD7Jnw==
# 5      kfWDI5wYFHdi9PtKFI9EPg==
# 6      3k2JCQ8Bp5oDwaI39ZJgHA==
# 7      kT9iINxmEtNoxGqiEuuu1w==
# 8      IS7hpLnmcFmoFQx5fYolyA==
# 9      FcreDj8X5CjkLfqOjlBKIQ==
# 10     sfVhE81w8VwY0KuIEpmLTg==
# 11     zQJ6Y7A4GmU0BHrQEGG6Zw==
# 12     vMR3ZftjD8zK2zQQfaehxw==
# 13     qYHD2XJpJVJTlVmVMyhftw==
# 14     xKFbYDl5iprg13oyD/ZSUA==
# 15     yEFu/7Nbau9SVX8b8Xmh4A==
# 16     gx9Ce6IBKdsmpKNDk4hgNA==
# 17     At+tZHbp9UVvvzPcIZNRrA==
# 18     nJoClk5m+2ITbwX4xW3JJA==
# 19     jTwINtRFyPuFao54O3d1WA==
# 20     4SehRyDLf04wMWM0Qz30ug==
# 21     41Mbq6IhIBKzrY6Bp9RLKQ==
# 22     uRIDZ7PsItUzQfUTgIYptw==
# 23     3k2JCQ8Bp5oDwaI39ZJgHA==
# 24     58TEJe+glBfijOvZOYny2A==
# 25     rlWIXTBO+VOa34+SpGyhlQ==
# 26     m166fujAW3mxeazX/Dgeyg==
# 27     x5kBDICFmcIF0+YeiaW07Q==
# 28     omqQiUb0rEkwsz9mAL+Bkw==
# 29     UMrxAIausSq1WdWIhvrBOw==
# ...                         ...
# 19562  e4zblouPEIx3n9BVs3w7aQ==
# 19563  U5KzPwt3Mkn1hZCR1B9Bxg==
# 19564  Omx3C/sIKz8shVdfLE1y7A==
# 19565  r3ekt+aj3O3sPA5ceTzJyA==
# 19566  bEl+LqEhi0l9CII7dkx13g==
# 16                    12:34:60              19074
# 17                    09:57:35              48579
# 18                    00:43:28              29331
# 19                    02:60:43              49428
# 20                    22:40:43              24173
# 21                    08:23:52              31585
# 22                    05:24:44              26938
# 23                    23:57:32              17149
# 24                    08:59:47              30453
# 25                    19:33:31              48555
# 26                    12:20:35              25385
# 27                    00:32:36              19430
# 28                    01:07:48              15034
# 29                    24:08:28              23008
# ...                        ...                ...
# 19562                 06:19:57              51168
# 19563                 04:57:54              24345
# 19564                 15:20:06              38984
# 19565                 18:34:48              13826
# 19566                 05:45:25              48850
# 19567                 04:48:35              24014
# 19568                 05:59:57              38196
# 19569                 20:39:53              24497
# 19570                 21:06:20              36437
# 19571                 14:19:19              50020
# 19572                 20:52:01              50766
# 19573                 02:43:20              31311
# 19574                 18:30:48              30936
# 19575                 10:45:46              30725
# 19576                 18:52:09              37351
# 19577                 01:11:20              32095
# 19578                 18:06:24              21531
# 19579                 07:02:28              53069
# 19580                 09:31:46              15960
# 19581                 06:18:02              51323
# 19582                 24:59:03              18869
# 19583                 06:22:46              25140
# 19584                 20:60:22              13433
# 19585                 18:00:25              41380
# 19586                 18:55:55              53990
# 19587                 01:58:19              51893
# 19588                 20:18:20              36828
# 19589                 13:13:12              49998
# 19590                 17:02:32              52634
# 19591                 17:06:10              14187
#
#                                          profile_tags  \
# 0                             {'tags': ['n19', 'n8']}
# 1                       {'tags': ['n6', 'n7', 'nim']}
# 2                {'tags': ['n0', 'n17', 'nim', 'da']}
# 3                                    {'tags': ['n4']}
# 4           {'tags': ['pro+aty', 'n19', 'da', 'b19']}
# 5                        {'tags': ['c1', 'n3', 'n9']}
# 6                                    {'tags': ['n3']}
# 7         {'tags': ['n15', 'c55', 'n14', 'n8', 'n3']}
# 8                      {'tags': ['n14', 'n15', 'n6']}
# 9             {'tags': ['n9', 'pro+aty', 'n2', 'n1']}
# 10                            {'tags': ['n6', 'a15']}
# 11                                  {'tags': ['b19']}
# 12         {'tags': ['n13', 'n4', 'n18', 'n2', 'n6']}
# 13                     {'tags': ['aty', 'n2', 'n15']}
# 14                                  {'tags': ['n13']}
# 15              {'tags': ['n12', 'da', 'n19', 'n11']}
# 16              {'tags': ['dfa', 'nim', 'n8', 'n14']}
# 17               {'tags': ['n15', 'n0', 'da', 'n18']}
# 18                       {'tags': ['n2', 'n1', 'da']}
# 19                                  {'tags': ['b19']}
# 20                {'tags': ['n6', 'aty', 'n3', 'n5']}
# 21                            {'tags': ['n12', 'n2']}
# 22                            {'tags': ['n1', 'aty']}
# 23                            {'tags': ['nim', 'n1']}
# 24                     {'tags': ['c1', 'n19', 'n15']}
# 25                            {'tags': ['n7', 'nim']}
# 26                      {'tags': ['n1', 'n12', 'n6']}
# 27        {'tags': ['n3', 'aty', 'c55', 'n7', 'n14']}
# 28                            {'tags': ['dfa', 'n1']}
# 29                                   {'tags': ['n7']}
# ...                                               ...
# 19562     {'tags': ['n19', 'n8', 'aty', 'n11', 'c1']}
# 19563      {'tags': ['n6', 'n1', 'n12', 'n5', 'n17']}
# 19564      {'tags': ['n9', 'n2', 'a15', 'n0', 'n13']}
# 19565                           {'tags': ['pro+aty']}
# 19566                               {'tags': ['n14']}
# 19567                        {'tags': ['n19', 'nim']}
# 19568  {'tags': ['n5', 'n11', 'n6', 'pro+aty', 'n0']}
# 19569     {'tags': ['n8', 'n19', 'n6', 'b19', 'aty']}
# 19570                        {'tags': ['n16', 'nim']}
# 19571                 {'tags': ['n13', 'n12', 'n14']}
# 19572     {'tags': ['n17', 'n11', 'n5', 'c1', 'nim']}
# 19573                               {'tags': ['n10']}
# 19574                  {'tags': ['n17', 'n11', 'n0']}
# 19575     {'tags': ['n12', 'c1', 'n6', 'n11', 'a15']}
# 19576                         {'tags': ['n1', 'n14']}
# 19577                                {'tags': ['n8']}
# 19578             {'tags': ['n0', 'n4', 'n8', 'n17']}
# 19579       {'tags': ['da', 'n0', 'n1', 'n6', 'nim']}
# 19580    {'tags': ['n15', 'c1', 'dfa', 'nim', 'aty']}
# 19581                                {'tags': ['da']}
# 19582                               {'tags': ['dfa']}
# 19583                        {'tags': ['n12', 'n16']}
# 19584                        {'tags': ['n14', 'c55']}
# 19585                                {'tags': ['n8']}
# 19586                        {'tags': ['n18', 'nim']}
# 19587                  {'tags': ['n3', 'n19', 'n12']}
# 19588                               {'tags': ['c55']}
# 19589                         {'tags': ['n1', 'a15']}
# 19590                    {'tags': ['n1', 'n5', 'n0']}
# 19591            {'tags': ['n6', 'n14', 'n5', 'a15']}
#
#                                               user_agent  \
# 0      Mozilla/5.0 (Linux; Android 6.0.1; SGP771 Buil...
# 1      Mozilla/5.0 (Linux; Android 5.0.2; SAMSUNG SM-...
# 2      Mozilla/5.0 (Linux; Android 6.0.1; SGP771 Buil...
# 3      Mozilla/5.0 (Linux; Android 6.0; HTC One X10 B...
# 4      Mozilla/5.0 (Linux; Android 7.0; Pixel C Build...
# 5      Mozilla/5.0 (Linux; Android 6.0.1; Nexus 6P Bu...
# 6      Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like M...
# 7      Mozilla/5.0 (iPhone9,4; U; CPU iPhone OS 10_0_...
# 8      Mozilla/5.0 (Apple-iPhone7C2/1202.466; U; CPU ...
# 9      Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15....
# 10     Mozilla/5.0 (Linux; Android 6.0; HTC One X10 B...
# 11     Mozilla/5.0 (Linux; Android 7.1.1; G8231 Build...
# 12     Mozilla/5.0 (Linux; Android 7.0; SM-G892A Buil...
# 13     Mozilla/5.0 (Linux; Android 6.0.1; SM-G920V Bu...
# 14     Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like M...
# 15     Mozilla/5.0 (Apple-iPhone7C2/1202.466; U; CPU ...
# 16     Mozilla/5.0 (Linux; Android 6.0.1; Nexus 6P Bu...
# 17     Mozilla/5.0 (Linux; Android 7.0; Pixel C Build...
# 18     Mozilla/5.0 (Linux; Android 6.0; HTC One X10 B...
# 19     Mozilla/5.0 (Linux; Android 6.0.1; E6653 Build...
# 20     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 21     Mozilla/5.0 (Linux; Android 6.0.1; SHIELD Tabl...
# 22     Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like M...
# 23     Mozilla/5.0 (Linux; Android 4.4.3; KFTHWI Buil...
# 24     Mozilla/5.0 (Linux; Android 7.0; SM-G892A Buil...
# 25     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 26     Mozilla/5.0 (Linux; Android 4.4.3; KFTHWI Buil...
# 27     Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like M...
# 28     Mozilla/5.0 (Linux; Android 7.0; SM-T827R4 Bui...
# 29     Mozilla/5.0 (Linux; Android 4.4.3; KFTHWI Buil...
# ...                                                  ...
# 19562                                                NaN
# 19563  Mozilla/5.0 (Linux; Android 5.1.1; SM-G928X Bu...
# 19564  Mozilla/5.0 (Linux; Android 5.0.2; SAMSUNG SM-...
# 19565  Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like M...
# 19566  Mozilla/5.0 (Linux; Android 6.0.1; E6653 Build...
# 19567  Mozilla/5.0 (iPhone9,3; U; CPU iPhone OS 10_0_...
# 19568  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15....
# 19569  Mozilla/5.0 (Linux; Android 6.0; HTC One X10 B...
# 19570  Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like M...
# 19571  Mozilla/5.0 (Linux; Android 6.0.1; E6653 Build...
# 19572  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 19573  Mozilla/5.0 (Linux; Android 7.0; SM-T827R4 Bui...
# 19574  Mozilla/5.0 (Linux; Android 6.0.1; SM-G935S Bu...
# 19575  Mozilla/5.0 (Linux; Android 6.0.1; SGP771 Buil...
# 19576  Mozilla/5.0 (Linux; Android 5.1.1; SM-G928X Bu...
# 19577  Mozilla/5.0 (Linux; Android 5.1.1; SM-G928X Bu...
# 19578  Mozilla/5.0 (Linux; Android 6.0.1; SHIELD Tabl...
# 19579  Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like M...
# 19580  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 19581  Mozilla/5.0 (Linux; Android 7.0; SM-T827R4 Bui...
# 19582  Mozilla/5.0 (Linux; Android 7.0; SM-G892A Buil...
# 19583  Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) Apple...
# 19584  Mozilla/5.0 (Linux; Android 5.0.2; SAMSUNG SM-...
# 19585  Mozilla/5.0 (Linux; Android 6.0.1; SM-G920V Bu...
# 19586  Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like M...
# 19587  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 19588  Mozilla/5.0 (Linux; Android 5.0.2; SAMSUNG SM-...
# 19589  Mozilla/5.0 (Linux; Android 5.1.1; SM-G928X Bu...
# 19590  Mozilla/5.0 (Apple-iPhone7C2/1202.466; U; CPU ...
# 19591  Mozilla/5.0 (Linux; Android 7.1.1; G8231 Build...
#
#                                                   reason  \
# 0      mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 1      mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 2      mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 3      mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 4      mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 5      mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 6      mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 7      mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 8      mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 9      mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 10     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 11     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 12     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 13     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 14     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 15     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 16     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 17     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 18     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 20     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 21     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 22     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 23     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 24     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 25     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 26     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 27     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 28     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 29     mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# ...                                                  ...
# 19562  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19563  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19564  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19565  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19566  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19567  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19568  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19569  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19570  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19571  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19572  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19573  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19574  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19575  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19576  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19577  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19578  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19579  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19580  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19581  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19582  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19583  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19584  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19585  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19586  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19587  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19588  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19589  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19590  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 19591  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
#
#       external_data_provider_first_name
# 0                            leidelaura
# 1                              diocezio
# 2                             veralucia
# 3                                venice
# 4                               darzisa
# 5                                teomar
# 6                                weigma
# 7                                  orna
# 8                               cleuber
# 9                               elisete
# 10                            macssilon
# 11                             climerio
# 12                             arzemira
# 13                              idiraci
# 14                                 walt
# 15                             esmailto
# 16                              adnicia
# 17                            aldemires
# 18                           'vanderlei
# 19                                vauir
# 20                               elivan
# 21                            valdumira
# 22                               geloci
# 23                             adenario
# 24                           emmanuelle
# 25                               creane
# 26                                tairo
# 27                              domasio
# 28                             mouracil
# 29                            edclaudio
# ...                                 ...
# 19562                          klebiano
# 19563                          leordina
# 19564                       ralismarque
# 19565                          aliandro
# 19566                         audemario
# 19567                         rosinilda
# 19568                         petrivone
# 19569                         canrobert
# 19570                           cleynan
# 19571                       melquesedek
# 19572                             eleon
# 19573                             benno
# 19574                           kyldary
# 19575                           estenio
# 19576                           arcidio
# 19577                             .jose
# 19578                         lankaster
# 19579                            gibson
# 19580                            anilze
# 19581                           rosiane
# 19582                         melquizes
# 19583                           silenir
# 19584                           rosanni
# 19585                         eliandson
# 19586                            adilca
# 19587                          acetides
# 19588                       laocidileia
# 19589                          idagomar
# 19590                         kettielen
# 19591                           alzildo
#
# [64592 rows x 10 columns]

# %% [markdown]
# Colunas com apenas 1 valor relevante também serão excluídas.

# %%
noVar = [feature for feature in combo_x_bl.columns if combo_x_bl[feature].nunique() == 1]
noVar
# Out:
# ['channel', 'external_data_provider_credit_checks_last_2_year']

# %%
combo_x_bl.drop(discVars, axis = 1, inplace = True)

combo_x_bl.drop(noVar, axis = 1, inplace = True)
combo_x_bl.reset_index(inplace=True)

# %%
def do_labelEncoding(df, columns, out = True):
    from sklearn.preprocessing import LabelEncoder
    df = df.copy()
    for column in columns:
        df[column+'_label'] = LabelEncoder().fit_transform(df[column].astype(str))
        df.drop(column, axis = 1, inplace = out)
    return df

# %%
import re
catFeatures = [feature for feature in combo_x_bl.columns if len(combo_x_bl[feature].unique()) <= 51 and  
               not bool(re.search("^n_", feature))]

# %%
combo_x_bl = do_labelEncoding(combo_x_bl, catFeatures)

# %%
combo_x_bl.dtypes
# Out:
# index                                                      int64
# score_3                                                  float64
# score_4                                                  float64
# score_5                                                  float64
# score_6                                                  float64
# risk_rate                                                float64
# last_amount_borrowed                                     float64
# credit_limit                                             float64
# income                                                   float64
# ok_since                                                 float64
# n_bankruptcies                                           float64
# n_defaulted_loans                                        float64
# n_accounts                                               float64
# n_issues                                                 float64
# application_time_in_funnel                                 int64
# external_data_provider_email_seen_before                 float64
# external_data_provider_fraud_score                         int64
# reported_income                                          float64
# score_1_label                                              int64
# score_2_label                                              int64
# last_borrowed_in_months_label                              int64
# facebook_profile_label                                     int64
# state_label                                                int64
# real_state_label                                           int64
# email_label                                                int64
# external_data_provider_credit_checks_last_month_label      int64
# external_data_provider_credit_checks_last_year_label       int64
# marketing_channel_label                                    int64
# shipping_state_label                                       int64
# dtype: object

# %% [markdown]
# # EDA

# %% [markdown]
# Usando os dados transformados, usaremos as correlações de Pearson para ter um primeiro olhar sobre as interações entre as variáveis e entender melhor como se relacionam. Vê-se, por exemplo, que as variáveis 'n_accounts' e 'n_issues' são totalmente colineares, o que é estranho.

# %%
plt.figure(figsize=(25,20))
plt.title('Pearson correlation of features', y=1.05, size=20)
sns.heatmap(pd.concat([combo_x_bl.iloc[0:45000, 1:],do_labelEncoding(acquisition[['target_default', 'target_fraud']], 
                                                    ['target_default', 'target_fraud'], out = False)], axis = 1).corr(), 
            linewidths=0.1, vmax=1.0, square=True, linecolor='white', annot=True)

# %% [markdown]
# ### 1.1

# %%
plt.figure(figsize=(5,5))

plt.title('Percentage of Default')
acquisition['target_default'].value_counts().plot(kind='pie', table=True, autopct='%1.1f%%',
counterclock=False, shadow=True)

# %%
# Iteração com as variáveis
for feature in [True, False]:
    # Subset em relação a cada
    subset = acquisition[acquisition['target_default'] == feature]
    
    # density plot
    sns.distplot(subset['risk_rate'], hist = False, kde = True,
                 kde_kws = {'shade': True, 'linewidth': 3},
                 label = subset['target_default'].unique())
# Plot formatting
plt.legend(prop={'size': 10}, title = 'target_default')
plt.title('Density Plot risk_rate')
plt.xlabel('risk_rate')
plt.ylabel('Density')
# Out:
# Text(0,0.5,'Density')

# %%
plt.title('Default x last_amount_borrowed')
sns.boxplot(y = 'last_amount_borrowed', x = 'target_default', data = acquisition)

# %%
plt.title('Default x score_1')
sns.countplot(y = 'score_1', hue = 'target_default', data = acquisition)

# %% [markdown]
# ###  1.2

# %%
plt.title('Default x target_fraud')
sns.countplot(y = 'target_fraud', hue = 'target_default', data = acquisition)

# %% [markdown]
# Boa indicação de que, talvez, não seja a melhor abordagem considerá-los um mesmo tipo apenas de fraude tendo em vista que a incidência de default é muito maior em fraud_friends_family

# %% [markdown]
# ### 1.3

# %%
spend.groupby(['ids', 'credit_line']).spends.rolling(3).sum().plot(kind = 'hist')
plt.title('Hist of pv_3m')
# Out:
# Text(0.5,1,'Hist of pv_3m')

# %% [markdown]
# Assim como visto acima, percebe-se uma distribuição extremamente concentrada em valores menores com alta dispersão em valores maiores. Isso indica que a média não seria um representante tão fiel da amostra, e que uma transformação logarítmica pode ser favorável à normalização da distribuição.

# %% [markdown]
# # Baseline Approach

# %% [markdown]
# ### Missing Values

# %%
#def create_dummies(df,column_names, limit = 51):
#    df = df.copy()
#    for feature in column_names:
#        if len(df[feature].unique())>2 and len(df[feature].unique()) <= limit:
#            dummies = pd.get_dummies(df[feature],prefix=feature,dummy_na=True, drop_first = False) # não sei ao certo se caga colocar true
#            df = pd.concat([df,dummies],axis=1)
#            df.drop(feature, axis = 1, inplace = True)
#    return df

# %%
#combo_x_bl_ohe = create_dummies(combo_x_bl, combo_x_bl.columns)
#for feature in acquisition_ohe.columns:
#    if acquisition_ohe[feature].nunique() == 1:
#        acquisition_ohe.drop([feature], axis = 1, inplace = True)

# %%
combo_x_bl.fillna(-1, inplace=True)

# %% [markdown]
# ### Array de Propensão a gasto

# %% [markdown]
# Mesmo em uma abordagem inicial, devido ao descoberto acima, usarei a mediana como melhor agregador de pagamentos por observação.

# %%
id_spends = spend.groupby('ids').spends.median()
spend_bl_y = acquisition[['ids']].join(id_spends, on = 'ids', how = 'left')
spend_bl_y.drop(['ids'], axis = 1, inplace = True); spend_bl_y.head()
# Out:
#      spends
# 0   686.395
# 1   935.980
# 2   320.930
# 3  4444.290
# 4   713.990

# %% [markdown]
# ### Array de Fraude

# %% [markdown]
# Abordagem inicial considerando todos os tipos de fraude como um só e os NaN como não fraudulentos.

# %%
fraud_bl_y.replace(np.nan, False, inplace = True)
fraud_bl_y.loc[fraud_bl_y.target_fraud != False] = True; fraud_bl_y.describe()
# Out:
#        target_fraud
# count         45000
# unique            2
# top           False
# freq          43478

# %% [markdown]
# ### Baseline Models

# %% [markdown]
# Parâmetros comuns a todo o trabalho

# %%
# Definindo o tamanho das amostras
teste_size = 0.3

# Garante que os resultados podem ser reproduzidos
seed = 666

# Quantidade de CV a serem usadas
num_folds = 5

# %% [markdown]
# Funções para otimizar teste de diversos modelos junto a CVs e avaliar desempenho nos dados de teste

# %%
# Import do módulo
from sklearn import model_selection
from sklearn.metrics import roc_auc_score, mean_squared_error

## Função para comparação
def compara_cv_modelos (X, y, modelos, num_folds = num_folds, seed = seed, scoring = 'roc_auc', Stratified = False):
    # Avaliando cada modelo
    resultados = []
    nomes = []
    
    for nome, modelo in modelos:
        if Stratified:
            kfold = model_selection.StratifiedKFold(n_splits = num_folds, random_state = seed)# stratified é necessário para class imbalance 
        else:
            kfold = model_selection.KFold(n_splits = num_folds, random_state = seed)
            
        cv_results = model_selection.cross_val_score(modelo, X, y, cv = kfold, scoring = scoring)
        resultados.append(cv_results)
        nomes.append(nome)
        msg = "%s: %f (%f)" % (nome, cv_results.mean(), cv_results.std())
        print(msg)
   # Boxplot para comparar os algoritmos
    fig = plt.figure()
    fig.suptitle('Comparação de Algoritmos de Classificação')
    ax = fig.add_subplot(111)
    plt.boxplot(resultados)
    ax.set_xticklabels(nomes)
    plt.show() 
    
def eval_model_c(X_treino, X_teste, y_treino, y_teste, modelos):
    for nome,modelo in modelos:
        modelo.fit(X_treino, y_treino)
        # Compute predicted probabilities: y_pred_prob
        y_pred_prob = modelo.predict_proba(X_teste)[:,1]
        # Compute and print AUC score
        msg = "%s: %f" % (nome, roc_auc_score(y_teste, y_pred_prob))
        print(msg)

def eval_model_r(X_treino, X_teste, y_treino, y_teste, modelos):
    for nome,modelo in modelos:
        modelo.fit(X_treino, y_treino)
        # Compute predicted values
        y_pred = modelo.predict(X_teste)
        # Compute and print AUC score
        msg = "%s: %f" % (nome, mean_squared_error(y_teste, y_pred))
        print(msg)

# %% [markdown]
# Tupples de algorítmos de regressão e classificação

# %%
## Classificação

# Import dos módulos
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
#from sklearn.svm import SVC # só usarei quando houver menos dimensões, senão demora demais para treinar
from xgboost import XGBClassifier

# Preparando os modelo
modelos_cla = []
modelos_cla.append(('LR', LogisticRegression()))
#modelos_cla.append(('LDA', LinearDiscriminantAnalysis()))
modelos_cla.append(('NB', GaussianNB()))
#modelos_cla.append(('KNN', KNeighborsClassifier()))
modelos_cla.append(('RF', RandomForestClassifier()))
#modelos.append(('SVM', SVC()))
modelos_cla.append(('XGB', XGBClassifier()))

## Regressão
# Import dos módulos
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
#from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import ElasticNet
#from sklearn.svm import SVC
from xgboost import XGBRegressor

# Preparando os modelo
modelos_reg = []
modelos_reg.append(('LR', LinearRegression()))
modelos_reg.append(('EN', ElasticNet()))
#modelos_reg.append(('KNN', KNeighborsRegressor()))
modelos_reg.append(('RF', RandomForestRegressor()))
#modelos_reg.append(('SVM', SVC()))
modelos_reg.append(('XGB', XGBRegressor()))

# %% [markdown]
# Separação de Teste e Treino

# %%
# Separando os dados em teste e treino
X_bl_treino = combo_x_bl.iloc[0:45000, 1:]
X_bl_teste = combo_x_bl.iloc[45001:, 1:]

# %% [markdown]
# ### Risco de Crédito

# %% [markdown]
# Retirada das observações com missing na variável target.

# %%
acquisition_bl_y.dropna(inplace = True)
X_bl_treino_credit = X_bl_treino.iloc[acquisition_bl_y.index, :]

# %% [markdown]
# Call da função com os parâmetros definidos acima.

# %%
compara_cv_modelos (X_bl_treino_credit, acquisition_bl_y, modelos_cla, Stratified = True)
# Out:
# LR: 0.498210 (0.005432)
# NB: 0.553555 (0.006170)
# RF: 0.690304 (0.001938)
# XGB: 0.765722 (0.006791)

# %% [markdown]
# ### Propensão a Gasto

# %% [markdown]
# Call da Função.

# %%
# Function call
compara_cv_modelos (X_bl_treino, spend_bl_y, modelos_reg, scoring = 'neg_mean_squared_error')
# Out:
# LR: -4707899.614408 (57507.790545)
# EN: -4704550.289086 (56532.872958)
# RF: -5336956.411870 (31680.251392)
# XGB: -4715659.561895 (55344.202857)

# %% [markdown]
# ### Risco de Fraude

# %% [markdown]
# Call da Função

# %%
compara_cv_modelos (X_bl_treino, fraud_bl_y, modelos_cla, Stratified = True)
# Out:
# LR: 0.495652 (0.021544)
# NB: 0.514588 (0.032721)
# RF: 0.586145 (0.007170)
# XGB: 0.747996 (0.009228)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Modificações Preliminares

# %% [markdown]
# Repetição dos passos realizados anteriormente, no entanto com o intuito de melhor tratar os dados para tentar aprimorar a análise. Vale ressaltar, também, a exclusão de 'n_issues' pela colinearidade plena.

# %%
acquisition_fe_y = acquisition[['target_default']].copy().astype('bool')
fraud_fe_y = acquisition[['target_fraud']].copy()
acquisition_X = acquisition.iloc[:, 2:-1].copy()
combo_x = pd.concat([acquisition_X, teste.iloc[:, 1:].copy()])

# %%
combo_x.drop(discVars, axis = 1, inplace = True)
combo_x.drop(noVar, axis = 1, inplace = True)
combo_x.drop(['n_issues'], axis = 1, inplace = True)
combo_x.reset_index(inplace=True)

# %% [markdown]
# ### Missing Values

# %%
# colunas com missing values
missingValueColumns = combo_x.columns[combo_x.isnull().any()].tolist()
combo_x_null = combo_x[missingValueColumns]

# %%
msno.bar(combo_x_null,figsize=(20,8),fontsize=18,labels=True)

# %%
msno.heatmap(combo_x_null,figsize=(20,8))

# %% [markdown]
# Pela total correlação desses missings relacionados acima, e sua baixa representatividade na amostra (0.01%), optarei pela exclusão dessas observações do modelo de treino e imputação quando nos dados de teste.

# %%
idMis = acquisition.loc[acquisition.score_1.isnull(), :].index.tolist()
for df in [combo_x, acquisition_fe_y, fraud_fe_y]:
    df.drop(idMis, inplace = True)

# %% [markdown]
# Demais ações em relação aos outros missings

# %% [markdown]
# Protocolo:
# - menor 0.5: ou serão mexidas, ou descartadas
# - maior 0.5: amostra considerável para se realizar imputação
#
# Features abaixo:
# - last_amount_borrowed, last_borrowed_in_months, ok_since: como os dados são referentes a ações que poderiam ou não acontecer, não há zeros na amostra, assumirei que os NaN são zeros (não tomaram)

# %%
combo_x.last_amount_borrowed.replace(np.nan, 0, inplace = True)
combo_x.last_borrowed_in_months.replace(np.nan, 0, inplace = True)
combo_x.ok_since.replace(np.nan, 0, inplace = True)

# %%
combo_x[['last_amount_borrowed', 'last_borrowed_in_months', 'ok_since']].hist()
plt.plot()
# Out:
# []

# %% [markdown]
# Agora, a análise da distribuição das variáveis numéricas faltantes para decidir o melhor método de imputação para cada uma. Como visto abaixo, as variáveis como distribuições mais normalizadas receberão imputação da média e as demais da mediana.

# %%
numFeatures = [feature for feature in combo_x.columns.tolist() if feature not in catFeatures]

# %%
missingValueColumns2 = combo_x.columns[combo_x.isnull().any()].tolist()
combo_x_null2 = combo_x[combo_x[numFeatures].columns & combo_x[missingValueColumns2].columns] 
combo_x_null2.hist(figsize=(10,10))
plt.plot()
# Out:
# []

# %% [markdown]
# Um ponto interessante é como os valores -999 e -1 em 'external_data_provider_email_seen_before'.

# %%
combo_x.external_data_provider_email_seen_before.unique()
# Out:
# array([  51.,   17.,    9.,   38.,   46.,   21.,   16.,   37.,    6.,
#          nan,   10.,   29.,   43.,   59.,   20.,   54.,   13.,   52.,
#           4.,   31.,   40.,   -1., -999.,   26.,   48.,   50.,    5.,
#           3.,   39.,   11.,    0.,   58.,   55.,    2.,    1.,   53.,
#          15.,   23.,   24.,   44.,   14.,   25.,   34.,   35.,   12.,
#          27.,   49.,    7.,   36.,   47.,   57.,    8.,   18.,   30.,
#          42.,   28.,   41.,   56.,   32.,   33.,   22.,   19.,   45.])

# %%
combo_x.external_data_provider_email_seen_before.replace(-999, np.nan, inplace=True)
combo_x.external_data_provider_email_seen_before.replace(-1, np.nan, inplace=True)
combo_x.external_data_provider_email_seen_before.plot('hist')

# %% [markdown]
# Por ter uma parência praticamente uniforme, usarei a moda como melhor representante médio da população.

# %%
def df_imputer (df,column_names, strat = 'mean', out = True):
    from sklearn.preprocessing import Imputer
    df = df.copy()
    imp = Imputer(missing_values=np.NaN, strategy=strat)
    for feature in column_names:
        imputed = imp.fit_transform(df[[feature]])
        imputed_df = pd.DataFrame(imputed, columns = [feature+'_imp'])
        df = pd.concat([df,imputed_df],axis=1)
        df.drop(feature, axis = 1, inplace = out)
    return df

# %%
combo_x.n_accounts.unique()
# Out:
# array([18., 14., 10., 19., 11.,  9.,  8.,  7., 16.,  6., 20.,  5., 13.,
#         4., 12., 23., 22., 15., 17., 21.,  3., 24., 28.,  2., 25., 30.,
#        27., 37., 26.,  1., 29., 33., 35., 34., 40., 49., 31., 32., 39.,
#        42., 36.,  0., 41., 38., nan, 45.])

# %%
from sklearn.preprocessing import Imputer
x = combo_x[['n_accounts']]
imp = Imputer(missing_values=np.NaN, strategy='mean')
imputed = imp.fit_transform(combo_x[['n_accounts']])
imputed_df = pd.DataFrame(imputed, columns = ['n_accounts'+'_imp'])
x = pd.concat([x,imputed_df],axis=1)
#x.drop('n_accounts', axis = 1, inplace = True)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64592 entries, 0 to 64591
# Data columns (total 2 columns):
# n_accounts        63807 non-null float64
# n_accounts_imp    64030 non-null float64
# dtypes: float64(2)
# memory usage: 1.5 MB

# %%
meanImp = ['n_accounts', 'risk_rate', 'score_3']
medianImp = ['credit_limit', 'income', 'n_bankruptcies', 'n_defaulted_loans', 'reported_income']
modaImp = ["external_data_provider_email_seen_before"]

# %%
combo_x.columns
# Out:
# Index(['index', 'score_1', 'score_2', 'score_3', 'score_4', 'score_5',
#        'score_6', 'risk_rate', 'last_amount_borrowed',
#        'last_borrowed_in_months', 'credit_limit', 'income', 'facebook_profile',
#        'state', 'real_state', 'ok_since', 'n_bankruptcies',
#        'n_defaulted_loans', 'n_accounts', 'application_time_in_funnel',
#        'email', 'external_data_provider_credit_checks_last_month',
#        'external_data_provider_credit_checks_last_year',
#        'external_data_provider_email_seen_before',
#        'external_data_provider_fraud_score', 'marketing_channel',
#        'reported_income', 'shipping_state'],
#       dtype='object')

# %%
combo_x.n_accounts.replace('nan', np.nan, inplace=True)
combo_x_imp = df_imputer(combo_x, meanImp)
combo_x_imp = df_imputer(combo_x_imp, medianImp, strat = 'median')
combo_x_imp = df_imputer(combo_x_imp, modaImp, strat = 'most_frequent')

# %%
combo_x_imp['n_accounts_imp'] = combo_x_imp['n_accounts_imp'].fillna(np.median(combo_x_imp['n_accounts_imp']))

# %%
combo_x_imp['n_accounts_imp'].unique()
# Out:
# array([18.        , 14.        , 10.        , 19.        , 11.        ,
#         9.        ,  8.        ,  7.        , 16.        ,  6.        ,
#        20.        ,  5.        , 13.        ,  4.        , 12.        ,
#        23.        , 22.        , 15.        , 17.        , 21.        ,
#         3.        , 24.        , 28.        ,  2.        , 25.        ,
#        30.        , 27.        , 37.        , 26.        ,  1.        ,
#        29.        , 33.        , 35.        , 34.        , 40.        ,
#        49.        , 31.        , 32.        , 39.        , 42.        ,
#        36.        ,  0.        , 41.        , 38.        , 10.68116351,
#        45.        ,         nan])

# %%
combo_x_imp.columns
# Out:
# Index(['index', 'score_1', 'score_2', 'score_4', 'score_5', 'score_6',
#        'last_amount_borrowed', 'last_borrowed_in_months', 'facebook_profile',
#        'state', 'real_state', 'ok_since', 'application_time_in_funnel',
#        'email', 'external_data_provider_credit_checks_last_month',
#        'external_data_provider_credit_checks_last_year',
#        'external_data_provider_fraud_score', 'marketing_channel',
#        'shipping_state', 'n_accounts_imp', 'risk_rate_imp', 'score_3_imp',
#        'credit_limit_imp', 'income_imp', 'n_bankruptcies_imp',
#        'n_defaulted_loans_imp', 'reported_income_imp',
#        'external_data_provider_email_seen_before_imp'],
#       dtype='object')

# %% [markdown]
# ### Normalização das Features numéricas

# %%
def do_scalling(df,column_names, out = True):
    from sklearn.preprocessing import StandardScaler
    df = df.copy()
    for feature in column_names:
        scaled = StandardScaler().fit_transform(df[[feature]])
        scaled_df = pd.DataFrame(scaled, columns = [feature+'_norm'])
        df = pd.concat([df,scaled_df],axis=1)
        df.drop(feature, axis = 1, inplace = True)
    return df

# %%
combo_x_imp.loc[:, [feature for feature in combo_x_imp.columns.tolist() if feature not in catFeatures]]
# Out:
#          index     score_4   score_5     score_6  last_amount_borrowed  \
# 0          0.0  101.800832  0.259555  108.427273              25033.92
# 1          1.0   97.062615  0.942655   92.002546                  0.00
# 2          2.0  100.027073  0.351918  112.892453               7207.92
# 3          3.0  101.599485  0.987673   94.902491                  0.00
# 4          4.0   98.474289  0.532539  118.126207                  0.00
# 5          5.0  101.837040  0.915389   90.711273                  0.00
# 6          6.0   98.958914  0.901736  108.609675                  0.00
# 7          7.0  100.342564  0.491610  115.954187                  0.00
# 8          8.0   95.201098  0.559745   94.657281               5019.53
# 9          9.0   97.608652  0.444594  102.905688                  0.00
# 10        10.0  104.047906  0.920695  105.966179               7524.90
# 11        11.0   99.907505  0.843765  105.703102                  0.00
# 12        12.0   98.979634  0.039586  100.886265                  0.00
# 13        13.0   98.485685  0.616826  108.788845                  0.00
# 14        14.0   99.199123  0.677613   97.849481                  0.00
# 15        15.0  103.684241  0.665613  100.613441              35027.98
# 16        16.0  101.552638  0.365306  108.721265                  0.00
# 64586              33249.0
# 64587             162291.0
# 64588              31047.0
# 64589              84059.0
# 64590             101977.0
# 64591              91816.0
#
# [64592 rows x 17 columns]

# %%
combo_x_norm = do_scalling(combo_x_imp, [feature for feature in combo_x_norm.columns.tolist() if feature not in meanImp])
# Out:
# Index(['index', 'score_1', 'score_2', 'last_borrowed_in_months',
#        'facebook_profile', 'state', 'real_state', 'n_bankruptcies',
#        'n_defaulted_loans', 'email',
#        'external_data_provider_credit_checks_last_month',
#        'external_data_provider_credit_checks_last_year', 'marketing_channel',
#        'score_4_norm', 'score_5_norm', 'score_6_norm',
#        'last_amount_borrowed_norm', 'ok_since_norm',
#        'application_time_in_funnel_norm',
#        'external_data_provider_fraud_score_norm', 'score_3_imp_norm',
#        'risk_rate_imp_norm', 'credit_limit_imp_norm', 'income_imp_norm',
#        'external_data_provider_email_seen_before_imp_norm',
#        'reported_income_imp_norm', 'n_accounts_imp_norm'],
#       dtype='object')

# %% [markdown]
# ### One Hot Encoding

# %% [markdown]
# One Hot Encoding das variáveis

# %%
def oneHotEncoder (df, columns, out = True):
    for column in columns:
        ohe = pd.get_dummies(df[column],prefix=column,dummy_na=False, drop_first = False) # não sei ao certo se caga colocar true
        df = pd.concat([df,ohe],axis=1)
        df.drop(column, axis = 1, inplace = out)
    return df

# %%
# n_issues é numerica e possui valores baixos
combo_x_ohe = create_dummies(combo_x_norm, 
                                    combo_x_norm.iloc[:, combo_x_norm.columns != 'n_accounts_imp_norm'].columns)
for feature in combo_x_ohe.columns:
    if combo_x_ohe[feature].nunique() == 1:
        combo_x_ohe.drop([feature], axis = 1, inplace = True)
# Out:
# index                                                  45000
# score_4_norm                                           64592
# score_5_norm                                           64592
# score_6_norm                                           64592
# last_amount_borrowed_norm                              20169
# ok_since_norm                                            104
# application_time_in_funnel_norm                          501
# external_data_provider_fraud_score_norm                 1001
# score_3_imp_norm                                          89
# risk_rate_imp_norm                                        83
# credit_limit_imp_norm                                  28260
# income_imp_norm                                        57431
# external_data_provider_email_seen_before_imp_norm         63
# reported_income_imp_norm                               54714
# n_accounts_imp_norm                                       46
# score_1_1Rk8w4Ucd5yR3KcqZzLdow==                           2
# score_1_4DLlLW62jReXaqbPaHp1vQ==                           2
# score_1_8k8UDR4Yx0qasAjkGrUZLw==                           2
# score_1_DGCQep2AE5QRkNCshIAlFQ==                           2
# score_1_e4NYDor1NOw6XKGE60AWFw==                           2
# score_1_fyrlulOiZ+5hoFqLa6UbDQ==                           2
# score_1_smzX0nxh5QlePvtVf6EAeg==                           2
# score_1_nan                                                2
# score_2_+2hzpeP1RWr8PEvL1WTUdw==                           2
# score_2_+CxEO4w7jv3QPI/BQbyqAA==                           2
# score_2_/tdlnWjXoZ3OjdtBXzdOJQ==                           2
# score_2_5/uMrqKj3OL/Xk5OrGx9fg==                           2
# score_2_55UK234RR1d7HIWJjmq9tw==                           2
# score_2_6J1ZMTzN5GKHXnhM4J1JbA==                           2
# score_2_7h+tk4z7O9brtBSe1rNjxA==                           2
#                                                        ...
# n_bankruptcies_nan                                         2
# n_defaulted_loans_0.0                                      2
# n_defaulted_loans_1.0                                      2
# n_defaulted_loans_2.0                                      2
# n_defaulted_loans_3.0                                      2
# n_defaulted_loans_5.0                                      2
# n_defaulted_loans_nan                                      2
# email_gmail.com                                            2
# email_gmaill.com                                           2
# email_hotmail.com                                          2
# email_hotmaill.com                                         2
# email_outlook.com                                          2
# email_spgov.com                                            2
# external_data_provider_credit_checks_last_month_0.0        2
# external_data_provider_credit_checks_last_month_1.0        2
# external_data_provider_credit_checks_last_month_2.0        2
# external_data_provider_credit_checks_last_month_3.0        2
# external_data_provider_credit_checks_last_year_0.0         2
# external_data_provider_credit_checks_last_year_1.0         2
# external_data_provider_credit_checks_last_year_nan         2
# marketing_channel_Facebook                                 2
# marketing_channel_Instagram                                2
# marketing_channel_Invite-email                             2
# marketing_channel_Invite-web                               2
# marketing_channel_LinkedIn                                 2
# marketing_channel_Radio-commercial                         2
# marketing_channel_Twitter                                  2
# marketing_channel_Waiting-list                             2
# marketing_channel_Website                                  2
# marketing_channel_nan                                      2
# Length: 159, dtype: int64

# %% [markdown]
# ### Array de Propensão a Gasto

# %% [markdown]
# Logaritimização da Feature para normalizar distribuição dos valores

# %%
spend_fe_y = spend_bl_y
spend_fe_y_ln = np.log(spend_fe_y)
spend_fe_y_ln.plot.hist()

# %% [markdown]
# ### Array de Risco de Fraude

# %% [markdown]
# Seria interessante criar um modelo multiclassificação devido ao diferente impacto que as 2 categorias de fraude possuem, porém, como não fica clara a possbildiade neste desafio, optarei pela abordagem mais simples identica a do baseline.

# %%
fraud_fe_y.replace(np.nan, False, inplace = True)
fraud_fe_y.loc[fraud_bl_y != False] = True; fraud_fe_y.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: target_fraud, dtype: bool

# %% [markdown]
# ### FE Models

# %% [markdown]
# Serão repetidas as mesmas etapas executadas acima, usando os mesmos parâmetros para verificar se houve os ganhos esperados com as transformações.

# %% [markdown]
# Separação em Dados de Teste e Treino

# %%
# Separando o array em componentes de input e output
X_treino = combo_x_ohe.iloc[0:45000, 1:]
X_teste = combo_x_ohe.iloc[45001:, 1:]

# %% [markdown]
# ### Risco de Crédito

# %% [markdown]
# Retirada das observações com missing na variável target.

# %%
acquisition_fe_y.dropna(inplace = True)
X_treino_credit = X_treino.iloc[acquisition_fe_y.index, :]

# %% [markdown]
# Import dos módulos, escolha dos modelos e call da função

# %%
# Function call
compara_cv_modelos(X_treino_credit, acquisition_fe_y, modelos_cla, Stratified = True)
# Out:
# LR: 0.713179 (0.010764)
# LDA: 0.710671 (0.010983)
# NB: 0.664042 (0.010683)
# KNN: 0.581962 (0.014488)
# RF: 0.640679 (0.011228)
# XGB: 0.725096 (0.011449)

# %% [markdown]
# Score dos melhores modelos nos dados de teste

# %% [markdown]
# ### Propensão a Gasto

# %% [markdown]
# Vale resaltar que optei por não usar a versão logaritmizada da variável target, pois os modelos não conseguiam criar features adequadas para a previsão, sendo sua própria média o melhor tomador de decisão, assim prossegui os testes com o mesmo target usado no início do trabalho.

# %% [markdown]
# Call da função.

# %%
# Function call
compara_cv_modelos (X_treino, spend_fe_y, modelos_reg, scoring = 'neg_mean_squared_error')
# Out:
# LR: -12522768860223088300654592.000000 (36497083399786078077452288.000000)
# EN: -4577698.652120 (46678.705124)
# KNN: -5499238.311924 (63691.174911)
# RF: -5116010.492901 (52073.623914)
# XGB: -4591517.038744 (46353.486628)

# %% [markdown]
# ### Risco de Fraude

# %% [markdown]
# Call da Função

# %%
compara_cv_modelos (X_treino, fraud_fe_y, modelos_cla, Stratified = True)
# Out:
# LR: 0.656307 (0.018987)
# LDA: 0.654249 (0.020058)
# NB: 0.523229 (0.011030)
# KNN: 0.509039 (0.011768)
# RF: 0.594537 (0.017042)
# XGB: 0.750393 (0.015080)

# %% [markdown]
# Com exceção do Risco de Fraude, todos os modelos demonstraram uma melhora de performance na média após a engenharia das variáveis. Por fim, usarei os modelos com melhor desempenho para realizar sua otimização.

# %% [markdown]
# ### Otimizações

# %% [markdown]
# Parâmetros a serem otimizados por modelo.

# %%
import scipy.stats as st

one_to_left = st.beta(10, 1)  
from_zero_positive = st.expon(0, 50)

param_xgb = {  
    "n_estimators": st.randint(3, 40),
    "max_depth": st.randint(3, 40),
    "learning_rate": st.uniform(0.05, 0.4),
    "colsample_bytree": one_to_left,
    "subsample": one_to_left,
    "gamma": st.uniform(0, 10),
    'reg_alpha': from_zero_positive,
    "min_child_weight": from_zero_positive,
}

# %% [markdown]
# Risco de Crédito

# %%
gsearch1 = model_selection.RandomizedSearchCV(XGBClassifier(nthreads=-1), param_xgb, n_iter=10,
                            n_jobs=-1, verbose=0, cv=num_folds,
                            scoring='roc_auc',random_state=seed)

gsearch1.fit(X_treino_credit, acquisition_fe_y)
gsearch1.best_params_, gsearch1.best_score_
# Out:
# ({'colsample_bytree': 0.8237982720390913,
#   'gamma': 7.561270438606042,
#   'learning_rate': 0.1696795345902315,
#   'max_depth': 11,
#   'min_child_weight': 98.66729335426714,
#   'n_estimators': 29,
#   'reg_alpha': 2.087762085297891,
#   'subsample': 0.9656969745622929},
#  0.7223021358337477)

# %% [markdown]
# Propensão a gasto

# %%
param_en = {"max_iter": [1, 5, 10],
                      "alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10],
                      "l1_ratio": np.arange(0.0, 1.0, 0.1)}

# %%
gsearch2 = model_selection.RandomizedSearchCV(ElasticNet(), param_en, n_iter=10,
                            n_jobs=1, verbose=0, cv=num_folds,
                            scoring='neg_mean_squared_error',random_state=seed)

gsearch2.fit(X_treino,spend_fe_y)
gsearch2.best_params_, gsearch2.best_score_
# Out:
# ({'max_iter': 5, 'l1_ratio': 0.5, 'alpha': 10}, -4576604.9635476265)

# %%
gsearch3 = model_selection.RandomizedSearchCV(XGBClassifier(nthreads=-1), param_xgb, n_iter=10,
                            n_jobs=1, verbose=0, cv=num_folds,
                            scoring='roc_auc',random_state=seed)

gsearch3.fit(X_treino, fraud_fe_y)
gsearch3.best_params_, gsearch3.best_score_
# Out:
# ({'colsample_bytree': 0.9925672460769812,
#   'gamma': 2.764625052041608,
#   'learning_rate': 0.23703419831067118,
#   'max_depth': 22,
#   'min_child_weight': 49.2290844643288,
#   'n_estimators': 30,
#   'reg_alpha': 15.621271381242193,
#   'subsample': 0.8182085933460475},
#  0.7445045954895739)

# %% [markdown]
# Assim como demonstrado acima, os modelos obtiveram nenhum ganho em relação aos modelos originais.

# %% [markdown]
# # Feature Importance

# %% [markdown]
# Abaixo, testaremos qual foi a importância de cada variável para as previsões.

# %% [markdown]
# Carregamento dos Modelos

# %%
xgb = XGBClassifier()
#en = ElasticNet(max_iter=10, l1_ratio=0.4, alpha=10)
en = ElasticNet()

# %% [markdown]
# Risco de Crédito

# %%
xgb_credit = xgb.fit(X_treino_credit, acquisition_fe_y) 

importances_credit = pd.DataFrame({'feature':X_treino_credit.columns,'importance':np.round(xgb_credit.feature_importances_,3)})
importances_credit_top = importances_credit.sort_values('importance',ascending=False).set_index('feature').head(n=20)

print(importances_credit_top)
importances_credit_top.plot.bar()
# Out:
#                                                    importance
# feature
# income_imp_norm                                         0.119
# external_data_provider_email_seen_before_imp_norm       0.112
# application_time_in_funnel_norm                         0.059
# score_1_4DLlLW62jReXaqbPaHp1vQ==                        0.057
# score_3_imp_norm                                        0.043
# score_1_DGCQep2AE5QRkNCshIAlFQ==                        0.040
# risk_rate_imp_norm                                      0.033
# n_accounts_imp_norm                                     0.030
# facebook_profile_True                                   0.027
# score_4_norm                                            0.026
# score_6_norm                                            0.026
# facebook_profile_False                                  0.024
# email_outlook.com                                       0.023
# score_1_smzX0nxh5QlePvtVf6EAeg==                        0.023
# score_5_norm                                            0.020
# last_borrowed_in_months_36.0                            0.019
# last_amount_borrowed_norm                               0.019
# score_1_fyrlulOiZ+5hoFqLa6UbDQ==                        0.016
# marketing_channel_Website                               0.016
# external_data_provider_fraud_score_norm                 0.014

# %% [markdown]
# Propensão a Gastos

# %%
en_s = en.fit(X_treino,spend_fe_y)

importances_s = pd.DataFrame({'feature':X_treino.columns,'importance':np.round(en_s.coef_,3)})
importances_s_top = importances_s.sort_values('importance',ascending=False).set_index('feature').head(n=20)

print(importances_s_top)
importances_s_top.plot.bar()
# Out:
#                                                     importance
# feature
# facebook_profile_nan                                     9.969
# score_1_DGCQep2AE5QRkNCshIAlFQ==                         9.789
# external_data_provider_credit_checks_last_month...       9.380
# score_2_RO7MTL+j4PH2gNzbhNTq/A==                         7.268
# external_data_provider_credit_checks_last_year_1.0       6.652
# marketing_channel_Invite-email                           6.146
# email_outlook.com                                        5.835
# marketing_channel_Website                                5.819
# score_2_rJZgTmANW3PjOCQLCcp4iQ==                         5.567
# score_4_norm                                             5.356
# last_borrowed_in_months_36.0                             5.128
# score_2_SaamrHMo23l/3TwXOWgVzw==                         4.869
# score_2_emS9xH8CLoRNie2uSmaDAQ==                         4.372
# state_rrVbgRNTRyB6auEycsRrpA==                           4.300
# external_data_provider_email_seen_before_imp_norm        4.230
# state_bNDXnbe7XAx/VUe+cbjDiw==                           4.214
# score_3_imp_norm                                         4.185
# score_1_1Rk8w4Ucd5yR3KcqZzLdow==                         3.933
# score_1_4DLlLW62jReXaqbPaHp1vQ==                         3.931
# n_accounts_imp_norm                                      3.901

# %% [markdown]
# Risco de Fraude

# %%
xgb_f = xgb.fit(X_treino,spend_fe_y) 

importances_f = pd.DataFrame({'feature':X_treino.columns,'importance':np.round(xgb_f.feature_importances_,3)})
importances_f_top = importances_f.sort_values('importance',ascending=False).set_index('feature').head(n=20)

print(importances_f_top)
importances_f_top.plot.bar()

# %% [markdown]
# # Submissions
